# %%
import matplotlib.pyplot as plt
import numpy as np 
from dnapolymer import *

# %%
a = range(4,10)
list(a)
# Out:
# [4, 5, 6, 7, 8, 9]

# %%
nmono = 200
rangemono = range(1,nmono+1)
LP = 2.2223
LD = 0.676
R = [wormlike_endtoend(LP, n, LD, R_max_out=True) for n in rangemono]
R_max = [R[i][1] for i in range(len(R))]
R = [R[i][0] for i in range(len(R))]
sqR = np.sqrt(R)

# %%
plt.plot(rangemono, R)

# %%
ratio1 = [R[i]/R_max[i] for i in range(len(R))]
ratio2 = [R_max[i]/sqR[i] for i in range(len(R))]

# %%
fig = plt.figure(figsize=(16,10))
plt.grid(color='0.25')
plot = plt.plot(rangemono, ratio1)
length_ratio = LP/LD
plt.axhline(2*LP)

# %%
fig = plt.figure(figsize=(10,5))
plt.grid(color='0.25')
plot = plt.plot(rangemono, ratio2)

# %%
fig = plt.figure(figsize=(10,5))
plt.grid(color='0.25')
plot = plt.plot(R_max, sqR)
line = plt.plot(np.linspace(0,130,10), np.linspace(0,130,10))

# %% [markdown]
# Ideal vs Real chain end to end distance distribution

# %%
x = np.linspace(0,3,50)
ideal = px_idealchain(x)
real = px_realchain(x)

# %%
fig = plt.figure(1)
plt.plot(x,ideal)

# %%
fig = plt.figure(2)
plot = plt.plot(x, real)

# %%
x
# Out:
# array([0.        , 0.06122449, 0.12244898, 0.18367347, 0.24489796,
#        0.30612245, 0.36734694, 0.42857143, 0.48979592, 0.55102041,
#        0.6122449 , 0.67346939, 0.73469388, 0.79591837, 0.85714286,
#        0.91836735, 0.97959184, 1.04081633, 1.10204082, 1.16326531,
#        1.2244898 , 1.28571429, 1.34693878, 1.40816327, 1.46938776,
#        1.53061224, 1.59183673, 1.65306122, 1.71428571, 1.7755102 ,
#        1.83673469, 1.89795918, 1.95918367, 2.02040816, 2.08163265,
#        2.14285714, 2.20408163, 2.26530612, 2.32653061, 2.3877551 ,
#        2.44897959, 2.51020408, 2.57142857, 2.63265306, 2.69387755,
#        2.75510204, 2.81632653, 2.87755102, 2.93877551, 3.        ])

# %%
p_circular = 4*np.pi*((0.1)**2)*sum(ideal[1:2])*0.1
p_circular
# Out:
# 0.1278290827590685
