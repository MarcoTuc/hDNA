# %%
import pandas as pd

# %%
met = pd.read_csv('datameeting.csv')
nos = pd.read_csv('datanosliding.csv')

# %%
met5 = met['5']
nos5 = nos['5']
msource = met['Source']; nsource = nos['Source']
mtarget = met['Target']; ntarget = nos['Target']

# %%
check = [m==n for m,n in zip(met5, nos5)]

# %%
for m, n, c, ms, mt, ns, nt in zip(met5, nos5, check, msource, mtarget, nsource, ntarget):
    print(c, '{:.3e}'.format(m), '{:.3e}'.format(n), ms, ns, mt, nt)
# Out:
# True 6.784e+07 6.784e+07 ..........+.......... ..........+.......... ...((((...+...))))... ...((((...+...))))...
# True 6.784e+07 6.784e+07 ..........+.......... ..........+.......... .((((.....+.....)))). ((((......+......))))
# True 6.784e+07 6.784e+07 ..........+.......... ..........+.......... .....((((.+.))))..... .....((((.+.)))).....
# True 6.784e+07 6.784e+07 ..........+.......... ..........+.......... ((((......+......)))) ......((((+))))......
# True 6.784e+07 6.784e+07 ..........+.......... ..........+.......... ..((((....+....)))).. ..((((....+....))))..
# True 6.784e+07 6.784e+07 ..........+.......... ..........+.......... ....((((..+..)))).... .((((.....+.....)))).
# True 6.784e+07 6.784e+07 ..........+.......... ..........+.......... ......((((+))))...... ....((((..+..))))....
# True 7.829e+02 7.829e+02 ...((((...+...))))... ...((((...+...))))... ..........+.......... ..........+..........
# ...

# %% [markdown]
# # FINAL NOTE:
# The old results were "right" thanks to the old wrongdoings of the zipping process that was making "two wrongs make one right" kind of results. stop looking at old simulations pls.
