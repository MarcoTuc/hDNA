# %%
import sys
sys.path.append('..')

# %load_ext autoreload
# %autoreload 2

# %%
from random import choice as choicerandom
from numpy.random import choice as choicenumpy
from hdna import *

# %%
M = Model('dna', '3D')
# A = Strand.random(M, 15)
A = Strand(M, 'ACCAAACCACCAAC')
# A = Strand(M, ''.join(['GACT' for i in range(5)]))
B = A.complementary()
# print(A.sequence+'+'+A.complementary().sequence)
c = Kinetwork(M, A, B, 3)
# Out:
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# (((((.........+.)))))........ L
# basepairs: 5
# dupdist:   8
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ........(((((.+.........))))) R
# basepairs: 5
# dupdist:   8
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ..(.(((.......+))).)......... L
# basepairs: 4
# dupdist:   7
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .........(.(((+.......))).).. R
# basepairs: 4
# dupdist:   7
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ((((..........+.....))))..... L
# basepairs: 4
# dupdist:   5
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .....((((.....+..........)))) R
# basepairs: 4
# dupdist:   5
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# (....((((.(...+).))))....)... L
# basepairs: 6
# dupdist:   3
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ...(....((((.(+...).))))....) R
# basepairs: 6
# dupdist:   3
#
#
# left:  8
# right: 8
# left:  7
# right: 7
# left:  5
# right: 5
# left:  3
# right: 3

# %%
c.overview
# Out:
# {'singlestranded': 1,
#  'off_register': 8,
#  'on_register': 12,
#  'zipping': 40,
#  'duplex': 1}

# %%
L = list(c.Graph.nodes.data('object'))
for l in L: 
    print(A.sequence+'+'+B.invert.sequence)
    print(l[0])
    print(      'object type:      ',l[1])
    print(      'basepairs:        ',l[1].total_nucleations)
    try: 
        print(  'duplex distance:  ',l[1].dpxdist)
        print(  'sliding side:     ',l[1].offregister)
    except AttributeError: print('bro')
    print('\n')
# Out:
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ..............+..............
# object type:       <hdna.complex.Complex object at 0x7f578ab43af0>
# basepairs:         0
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# (((((.........+.)))))........
# object type:       <hdna.complex.Sliding object at 0x7f578ab661d0>
# basepairs:         5
# duplex distance:   8
# sliding side:      left
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ..(.(((.......+))).).........
# object type:       <hdna.complex.Sliding object at 0x7f578ab65330>
# basepairs:         4
# duplex distance:   7
# sliding side:      left
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ((((..........+.....)))).....
# object type:       <hdna.complex.Sliding object at 0x7f578ab666e0>
# basepairs:         4
# duplex distance:   5
# sliding side:      left
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# (....((((.(...+).))))....)...
# object type:       <hdna.complex.Sliding object at 0x7f578ab64700>
# basepairs:         6
# duplex distance:   3
# sliding side:      left
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ...(....((((.(+...).))))....)
# object type:       <hdna.complex.Sliding object at 0x7f578ab66b30>
# basepairs:         6
# duplex distance:   3
# sliding side:      right
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .....((((.....+..........))))
# object type:       <hdna.complex.Sliding object at 0x7f578ab66950>
# basepairs:         4
# duplex distance:   5
# sliding side:      right
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .........(.(((+.......))).)..
# object type:       <hdna.complex.Sliding object at 0x7f578ab71b40>
# basepairs:         4
# duplex distance:   7
# sliding side:      right
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ........(((((.+.........)))))
# object type:       <hdna.complex.Sliding object at 0x7f578ab64250>
# basepairs:         5
# duplex distance:   8
# sliding side:      right
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# (((...........+...........)))
# object type:       <hdna.complex.Complex object at 0x7f578ab72dd0>
# basepairs:         3
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .(((..........+..........))).
# object type:       <hdna.complex.Complex object at 0x7f578ab73160>
# basepairs:         3
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ..(((.........+.........)))..
# object type:       <hdna.complex.Complex object at 0x7f578ab70d60>
# basepairs:         3
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ...(((........+........)))...
# object type:       <hdna.complex.Complex object at 0x7f578ab73490>
# basepairs:         3
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ....(((.......+.......)))....
# object type:       <hdna.complex.Complex object at 0x7f578ab3df90>
# basepairs:         3
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .....(((......+......))).....
# object type:       <hdna.complex.Complex object at 0x7f578ab3d660>
# basepairs:         3
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ......(((.....+.....)))......
# object type:       <hdna.complex.Complex object at 0x7f578ab70e50>
# basepairs:         3
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .......(((....+....))).......
# object type:       <hdna.complex.Complex object at 0x7f578ab3f400>
# basepairs:         3
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ........(((...+...)))........
# object type:       <hdna.complex.Complex object at 0x7f578ab66d70>
# basepairs:         3
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .........(((..+..))).........
# object type:       <hdna.complex.Complex object at 0x7f578ab0e980>
# basepairs:         3
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ..........(((.+.)))..........
# object type:       <hdna.complex.Complex object at 0x7f578ab0f820>
# basepairs:         3
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ...........(((+)))...........
# object type:       <hdna.complex.Complex object at 0x7f578ab3fac0>
# basepairs:         3
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ((((..........+..........))))
# object type:       <hdna.complex.Zippo object at 0x7f578ab65720>
# basepairs:         4
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# (((((.........+.........)))))
# object type:       <hdna.complex.Zippo object at 0x7f578ab73a90>
# basepairs:         5
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ((((((........+........))))))
# object type:       <hdna.complex.Zippo object at 0x7f578ab644f0>
# basepairs:         6
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# (((((((.......+.......)))))))
# object type:       <hdna.complex.Zippo object at 0x7f578ab3fbe0>
# basepairs:         7
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ((((((((......+......))))))))
# object type:       <hdna.complex.Zippo object at 0x7f578ab65810>
# basepairs:         8
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# (((((((((.....+.....)))))))))
# object type:       <hdna.complex.Zippo object at 0x7f578ab0e9b0>
# basepairs:         9
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ((((((((((....+....))))))))))
# object type:       <hdna.complex.Zippo object at 0x7f578ab0e7a0>
# basepairs:         10
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# (((((((((((...+...)))))))))))
# object type:       <hdna.complex.Zippo object at 0x7f578ab0e050>
# basepairs:         11
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ((((((((((((..+..))))))))))))
# object type:       <hdna.complex.Zippo object at 0x7f578ab0fee0>
# basepairs:         12
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# (((((((((((((.+.)))))))))))))
# object type:       <hdna.complex.Zippo object at 0x7f578ab71c90>
# basepairs:         13
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .(((((........+........))))).
# object type:       <hdna.complex.Zippo object at 0x7f578ab3dae0>
# basepairs:         5
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ..(((((.......+.......)))))..
# object type:       <hdna.complex.Zippo object at 0x7f578ab3e080>
# basepairs:         5
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .(((((((......+......))))))).
# object type:       <hdna.complex.Zippo object at 0x7f578ab0f370>
# basepairs:         7
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ...(((((......+......)))))...
# object type:       <hdna.complex.Zippo object at 0x7f578ab3d600>
# basepairs:         5
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ..(((((((.....+.....)))))))..
# object type:       <hdna.complex.Zippo object at 0x7f578ab0f010>
# basepairs:         7
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .(((((((((....+....))))))))).
# object type:       <hdna.complex.Zippo object at 0x7f57ed748d60>
# basepairs:         9
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ....(((((.....+.....)))))....
# object type:       <hdna.complex.Zippo object at 0x7f578ab0f100>
# basepairs:         5
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ...(((((((....+....)))))))...
# object type:       <hdna.complex.Zippo object at 0x7f578ab0ea70>
# basepairs:         7
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ..(((((((((...+...)))))))))..
# object type:       <hdna.complex.Zippo object at 0x7f578ab3dff0>
# basepairs:         9
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .(((((((((((..+..))))))))))).
# object type:       <hdna.complex.Zippo object at 0x7f578ab3e200>
# basepairs:         11
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .....(((((....+....))))).....
# object type:       <hdna.complex.Zippo object at 0x7f578ab3ceb0>
# basepairs:         5
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ....(((((((...+...)))))))....
# object type:       <hdna.complex.Zippo object at 0x7f578ab0ee00>
# basepairs:         7
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ...(((((((((..+..)))))))))...
# object type:       <hdna.complex.Zippo object at 0x7f57ed74abc0>
# basepairs:         9
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ..(((((((((((.+.)))))))))))..
# object type:       <hdna.complex.Zippo object at 0x7f578ab640d0>
# basepairs:         11
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .(((((((((((((+))))))))))))).
# object type:       <hdna.complex.Zippo object at 0x7f57ed777640>
# basepairs:         13
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ......(((((...+...)))))......
# object type:       <hdna.complex.Zippo object at 0x7f57ed74bd60>
# basepairs:         5
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .....(((((((..+..))))))).....
# object type:       <hdna.complex.Zippo object at 0x7f57ed74a890>
# basepairs:         7
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ....(((((((((.+.)))))))))....
# object type:       <hdna.complex.Zippo object at 0x7f57ed74b9d0>
# basepairs:         9
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ...(((((((((((+)))))))))))...
# object type:       <hdna.complex.Zippo object at 0x7f57ed7775e0>
# basepairs:         11
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ..((((((((((((+))))))))))))..
# object type:       <hdna.complex.Zippo object at 0x7f57ed790a30>
# basepairs:         12
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .......(((((..+..))))).......
# object type:       <hdna.complex.Zippo object at 0x7f57ed74b6a0>
# basepairs:         5
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ......(((((((.+.)))))))......
# object type:       <hdna.complex.Zippo object at 0x7f57ed7498a0>
# basepairs:         7
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .....(((((((((+))))))))).....
# object type:       <hdna.complex.Zippo object at 0x7f57ed775a50>
# basepairs:         9
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ....((((((((((+))))))))))....
# object type:       <hdna.complex.Zippo object at 0x7f57ed777850>
# basepairs:         10
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ........(((((.+.)))))........
# object type:       <hdna.complex.Zippo object at 0x7f578ab72980>
# basepairs:         5
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .......(((((((+))))))).......
# object type:       <hdna.complex.Zippo object at 0x7f57ed74bca0>
# basepairs:         7
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ......((((((((+))))))))......
# object type:       <hdna.complex.Zippo object at 0x7f57ed749840>
# basepairs:         8
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# .........(((((+))))).........
# object type:       <hdna.complex.Zippo object at 0x7f57ed775300>
# basepairs:         5
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ........((((((+))))))........
# object type:       <hdna.complex.Zippo object at 0x7f57ed775fc0>
# basepairs:         6
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ..........((((+))))..........
# object type:       <hdna.complex.Zippo object at 0x7f57ed7774c0>
# basepairs:         4
# bro
#
#
# ACCAAACCACCAAC+GTTGGTGGTTTGGT
# ((((((((((((((+))))))))))))))
# object type:       <hdna.complex.Complex object at 0x7f578ab43ac0>
# basepairs:         14
# bro

# %%
c.save_graph('.','trial')
