# %%
import sys
sys.path.append('..')

# %load_ext autoreload
# %autoreload 2

# %%
from random import choice as choicerandom
from numpy.random import choice as choicenumpy
from hdna import *

# %%
M = Model('dna', '3D')
# A = Strand.random(M, 30)
# A = Strand(M, 'ACCAAACCACCAAC')
A = Strand(M, ''.join(['GACT' for i in range(5)]))
B = A.complementary()
print(A.sequence)
print(A.complementary().sequence)
kinet = Kinetwork(M, A, B, 3)
# Out:
# GACTGACTGACTGACTGACT
# CTGACTGACTGACTGACTGA
# GACTGACTGACTGACTGACT+AGTCAGTCAGTCAGTCAGTC
# ((((................+))))................ L 4
#
#
# GACTGACTGACTGACTGACT+AGTCAGTCAGTCAGTCAGTC
# ................((((+................)))) R 4
#
#
# GACTGACTGACTGACTGACT+AGTCAGTCAGTCAGTCAGTC
# ((((((((............+))))))))............ L 8
#
#
# GACTGACTGACTGACTGACT+AGTCAGTCAGTCAGTCAGTC
# ............((((((((+............)))))))) R 8
#
#
# GACTGACTGACTGACTGACT+AGTCAGTCAGTCAGTCAGTC
# ((((((((((((........+))))))))))))........ L 12
#
#
# GACTGACTGACTGACTGACT+AGTCAGTCAGTCAGTCAGTC
# ........((((((((((((+........)))))))))))) R 12
#
#
# GACTGACTGACTGACTGACT+AGTCAGTCAGTCAGTCAGTC
# ((((((((((((((((....+)))))))))))))))).... L 16
#
#
# GACTGACTGACTGACTGACT+AGTCAGTCAGTCAGTCAGTC
# ....((((((((((((((((+....)))))))))))))))) R 16

# %%
kinet.Graph.edges()
# Out:
# EdgeView([('..............................+..............................', '....(((.......................+.......................)))....'), ('..............................+..............................', '........(((...................+...................)))........'), ('..............................+..............................', '..........(((.................+.................)))..........'), ('..............................+..............................', '.............(((..............+..............))).............'), ('..............................+..............................', '.(((..........................+..........................))).'), ('..............................+..............................', '.......(((....................+....................))).......'), ('..............................+..............................', '...................(((........+........)))...................'), ('..............................+..............................', '.........(((..................+..................))).........'), ('..............................+..............................', '.................(((..........+..........))).................'), ('..............................+..............................', '...........(((................+................)))...........'), ('..............................+..............................', '...............(((............+............)))...............'), ('..............................+..............................', '..(((.........................+.........................)))..'), ('..............................+..............................', '................(((...........+...........)))................'), ('..............................+..............................', '..............(((.............+.............)))..............'), ('..............................+..............................', '..................(((.........+.........)))..................'), ('..............................+..............................', '......(((.....................+.....................)))......'), ('..............................+..............................', '.....(((......................+......................))).....'), ('..............................+..............................', '.........................(((..+..))).........................'), ('..............................+..............................', '..........................(((.+.)))..........................'), ('..............................+..............................', '............(((...............+...............)))............'), ('..............................+..............................', '......................(((.....+.....)))......................'), ('..............................+..............................', '...........................(((+)))...........................'), ('..............................+..............................', '.....................(((......+......))).....................'), ('..............................+..............................', '........................(((...+...)))........................'), ('..............................+..............................', '....................(((.......+.......)))....................'), ('..............................+..............................', '...(((........................+........................)))...'), ('..............................+..............................', '(((...........................+...........................)))'), ('..............................+..............................', '.......................(((....+....))).......................'), ('..............................+..............................', '(((...(..((...................+..))..)...))).................'), ('..............................+..............................', '.................(((...(..((..+...................))..)...)))'), ('............................ ...
